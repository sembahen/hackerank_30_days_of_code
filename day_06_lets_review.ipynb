# %%
test_cases=int(input())
for item in range(test_cases):
  word=input()
  even_integers =""
  odd_integers=""
  for i in range(len(word)):
    if i%2==0:
      even_integers+=word[i]
    else:
      odd_integers+=word[i]
  print("{} {}".format(even_integers, odd_integers))
# Out:
# 2
# What
# Wa ht
# Wonderful
# Wnefl odru
