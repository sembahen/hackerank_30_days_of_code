# %%
size=int(input())
list=[]
for x in range(size):
 integer=int(input())
 list.append(integer)
print(list)
new_list=list[::-1]
print(new_list)
print(*new_list, sep= " ")
# Out:
# 4
# 3
# 2
# 7
# 8
# [3, 2, 7, 8]
# [8, 7, 2, 3]
# 8 7 2 3

# %%
n = int(input())

arr = list(map(int, input().rstrip().split()))

reversed_array=[]
for i in range(n):
  reversed_array.append(arr[n-i-1])
#
#
output_string=''
for i in range(len(reversed_array)):
  output_string+=str(reversed_array[i]) + ' '

print(output_string)
#
#
#the code below can replace the 
print(' '.join(str(i) for i in reversed_array))
