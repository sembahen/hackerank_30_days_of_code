# %%
#input string
input_string=str(input())

#On the first line, we print the string literal Hello, World.. 
print("Hello, world ..")

#on the second line we print the contents of the input string variable
print(input_string)
# Out:
# Welcome to 30 days of code
# Hello, world ..
# Welcome to 30 days of code
